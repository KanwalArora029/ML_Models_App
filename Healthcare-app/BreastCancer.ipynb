# %% [markdown]
# ## Breast Cancer EDA

# %%
# Importing Liabraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Importing Database from folder
df_cancer = pd.read_csv('data/cancer.csv')
df_cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Checking the null values in the database 
df_cancer.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Droping the null values
df_cancer = df_cancer.drop('Unnamed: 32', axis=1)

# %%
# Updated dataset
df_cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Descrip
df_cancer.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
# getting all columns
df_cancer.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df_cancer = df_cancer.drop('id', axis=1)

# %%
df_cancer.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_0dd7a_row0_col0,#T_0dd7a_row0_col2,#T_0dd7a_row1_col1,#T_0dd7a_row2_col0,#T_0dd7a_row2_col2,#T_0dd7a_row3_col3,#T_0dd7a_row4_col4,#T_0dd7a_row5_col5,#T_0dd7a_row6_col6,#T_0dd7a_row7_col7,#T_0dd7a_row8_col8,#T_0dd7a_row9_col9,#T_0dd7a_row10_col10,#T_0dd7a_row11_col11,#T_0dd7a_row12_col12,#T_0dd7a_row13_col13,#T_0dd7a_row14_col14,#T_0dd7a_row15_col15,#T_0dd7a_row16_col16,#T_0dd7a_row17_col17,#T_0dd7a_row18_col18,#T_0dd7a_row19_col19,#T_0dd7a_row20_col20,#T_0dd7a_row21_col21,#T_0dd7a_row22_col22,#T_0dd7a_row23_col23,#T_0dd7a_row24_col24,#T_0dd7a_row25_col25,#T_0dd7a_row26_col26,#T_0dd7a_row27_col27,#T_0dd7a_row28_col28,#T_0dd7a_row29_col29{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_0dd7a_row0_col1,#T_0dd7a_row4_col2,#T_0dd7a_row4_col20,#T_0dd7a_row4_col22,#T_0dd7a_row24_col22,#T_0dd7a_row27_col9{
#             background-color:  #b7cff9;
#             color:  #000000;
# ...

# %%
df_cancer.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df_cancer.diagnosis = le.fit_transform(df_cancer.diagnosis)
df_cancer.diagnosis
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int32

# %%
import seaborn as sns
ax = sns.countplot(df_cancer.diagnosis, label="Count")
B,M = df_cancer.diagnosis.value_counts()
print("Number of Benign: {}".format(B))
print("Number of Malignant: {}".format(M))
# Out:
# Number of Benign: 357
# Number of Malignant: 212

# %% [markdown]
# #### Diagnosis
# * M = malignant ==> 1
# * B = benign ==> 0

# %%
df_cancer.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_dec92_row0_col0,#T_dec92_row1_col1,#T_dec92_row1_col3,#T_dec92_row2_col2,#T_dec92_row3_col1,#T_dec92_row3_col3,#T_dec92_row4_col4,#T_dec92_row5_col5,#T_dec92_row6_col6,#T_dec92_row7_col7,#T_dec92_row8_col8,#T_dec92_row9_col9,#T_dec92_row10_col10,#T_dec92_row11_col11,#T_dec92_row12_col12,#T_dec92_row13_col13,#T_dec92_row14_col14,#T_dec92_row15_col15,#T_dec92_row16_col16,#T_dec92_row17_col17,#T_dec92_row18_col18,#T_dec92_row19_col19,#T_dec92_row20_col20,#T_dec92_row21_col21,#T_dec92_row22_col22,#T_dec92_row23_col23,#T_dec92_row24_col24,#T_dec92_row25_col25,#T_dec92_row26_col26,#T_dec92_row27_col27,#T_dec92_row28_col28,#T_dec92_row29_col29,#T_dec92_row30_col30{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_dec92_row0_col1,#T_dec92_row0_col3,#T_dec92_row3_col28,#T_dec92_row23_col0,#T_dec92_row28_col24{
#             background-color:  #ee8669;
#             color:  #000000;
# ...

# %% [markdown]
# #### This feautres had a corralation valus < 0.07 with the target columns
# fractal_dimension_mean / texture_se / smoothness_se / symmetry_se / fractal_dimension_se

# %%
# we need to drop above column which has correlation less than 0.07
df_cancer = df_cancer.drop(['fractal_dimension_mean', 'texture_se', 'smoothness_se', 'symmetry_se', 'fractal_dimension_se'], axis=1)

# %%
df_cancer.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'radius_se', 'perimeter_se',
#        'area_se', 'compactness_se', 'concavity_se', 'concave points_se',
#        'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
#        'smoothness_worst', 'compactness_worst', 'concavity_worst',
#        'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
# Feature Selection
plt.rcParams['figure.figsize']=15,6 
sns.set_style("darkgrid")

x = df_cancer.drop('diagnosis',axis=1)
y = df_cancer.diagnosis

from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
model.fit(x,y)
print(model.feature_importances_) 
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(15).plot(kind='barh')
plt.title('the most 15 important feature are')
plt.show()
# Out:
# [0.06669308 0.02516432 0.06435543 0.06065049 0.0111848  0.03452306
#  0.07751286 0.0809735  0.00649921 0.02004033 0.01889525 0.02303625
#  0.01112809 0.00863219 0.01538902 0.10278606 0.03004611 0.06981646
#  0.06199292 0.01923348 0.02489531 0.04143371 0.1011401  0.01369594
#  0.01028202]

# %%
df_cancer=df_cancer.drop(['texture_mean','smoothness_mean','compactness_mean','symmetry_mean','perimeter_se','compactness_se','concavity_se','concave points_se','smoothness_worst','symmetry_worst','fractal_dimension_worst'],axis=1)

# %%
sns.boxplot(x=df_cancer['concave points_worst'])

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
print(x.shape)
print(y.shape)
# Out:
# (569, 25)
# (569,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
# Making Confusion Matrix and calculating accuracy score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

model = LogisticRegression()

#Fit the model
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

mylist = []
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
# accuracy score
acc_logreg = accuracy_score(y_test, y_pred)

mylist.append(acc_logreg)
print(cm)
print((acc_logreg)*100,'%')
# Out:
# [[99  0]
#  [ 6 66]]
# 96.49122807017544 %
